# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fertility = pd.read_csv('spiced_projects/sandbox/week_1/data/gapminder_total_fertility.csv',index_col=0)

# %%
fertility.dropna(inplace=True)

# %%
print(fertility.shape)
# Out:
# (199, 216)

# %%
fertility.head()
# Out:
#                       1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Afghanistan           7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Albania               4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria               6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# Angola                6.93  6.93  6.93  6.93  6.93  6.93  6.93  6.94  6.94
# Antigua and Barbuda   5.00  5.00  4.99  4.99  4.99  4.98  4.98  4.97  4.97
#
#                       1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# Total fertility rate        ...
# Afghanistan           7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Albania               4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria               6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
# Angola                6.94  ...  6.60  6.52  6.43  6.33  6.22  6.10  5.98
# Antigua and Barbuda   4.97  ...  2.20  2.18  2.16  2.15  2.13  2.12  2.10
#
# ...

# %%
life = pd.read_excel('C:/Users/96650/OneDrive/Desktop/spiced_projects/sandbox/week_1/data/gapminder_lifeexpectancy.xlsx', index_col=0)

# %%
life.dropna(inplace=True)

# %%
print(life.shape)
# Out:
# (201, 217)

# %%
life.head()
# Out:
#                       1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Afghanistan          28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Albania              35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria              28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# Angola               26.98  26.98  26.98  26.98  26.98  26.98  26.98  26.98
# Antigua and Barbuda  33.54  33.54  33.54  33.54  33.54  33.54  33.54  33.54
#
#                       1808   1809  ...  2007  2008  2009  2010  2011  2012  \
# Life expectancy                    ...
# Afghanistan          28.13  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4
# Albania              35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5
# Algeria              28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2
# Angola               26.98  26.98  ...  56.2  56.7  57.1  57.6  58.1  58.5
# Antigua and Barbuda  33.54  33.54  ...  75.3  75.5  75.7  75.8  75.9  76.1
#
# ...

# %%
fertility.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %%
fertility.columns = fertility.columns.astype(int)

# %%
fertility.columns,life.columns
# Out:
# (Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#              ...
#              2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015],
#             dtype='int64', length=216),
#  Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#              ...
#              2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#             dtype='int64', length=217))

# %%
fertility.index,life.index
# Out:
# (Index(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Antigua and Barbuda',
#         'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria',
#         ...
#         'Uzbekistan', 'Vanuatu', 'Venezuela', 'West Bank and Gaza',
#         'Western Sahara', 'Vietnam', 'Virgin Islands (U.S.)', 'Yemen', 'Zambia',
#         'Zimbabwe'],
#        dtype='object', name='Total fertility rate', length=199),
#  Index(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Antigua and Barbuda',
#         'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria',
#         ...
#         'Vanuatu', 'Venezuela', 'West Bank and Gaza', 'Western Sahara',
#         'Vietnam', 'Virgin Islands (U.S.)', 'Yemen', 'Zambia', 'Zimbabwe',
#         'South Sudan'],
#        dtype='object', name='Life expectancy', length=201))

# %%
fertility.index.name = 'country'
#fert.rename({'Total fertility rate': 'country'}, axis = 1, inplace = True)
fertility.head()
# Out:
#                      1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# country
# Afghanistan          7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Albania              4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria              6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# Angola               6.93  6.93  6.93  6.93  6.93  6.93  6.93  6.94  6.94
# Antigua and Barbuda  5.00  5.00  4.99  4.99  4.99  4.98  4.98  4.97  4.97
#
#                      1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# country                    ...
# Afghanistan          7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Albania              4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria              6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
# Angola               6.94  ...  6.60  6.52  6.43  6.33  6.22  6.10  5.98
# Antigua and Barbuda  4.97  ...  2.20  2.18  2.16  2.15  2.13  2.12  2.10
#
#                      2013  2014  2015
# ...

# %%
fertility = fertility.reset_index()

# %%
fertility.head()
# Out:
#                country  1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# 0          Afghanistan  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# 1              Albania  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# 2              Algeria  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# 3               Angola  6.93  6.93  6.93  6.93  6.93  6.93  6.93  6.94  6.94
# 4  Antigua and Barbuda  5.00  5.00  4.99  4.99  4.99  4.98  4.98  4.97  4.97
#
#    ...  2006  2007  2008  2009  2010  2011  2012  2013  2014  2015
# 0  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14  4.90  4.68  4.47
# 1  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76  1.77  1.78  1.78
# 2  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82  2.80  2.76  2.71
# 3  ...  6.60  6.52  6.43  6.33  6.22  6.10  5.98  5.86  5.75  5.65
# 4  ...  2.20  2.18  2.16  2.15  2.13  2.12  2.10  2.09  2.08  2.06
#
# [5 rows x 217 columns]

# %%
melt_fertility = fertility.melt(id_vars='country', var_name='year', value_name='fertility_rate')

# %%
melt_fertility.head()
# Out:
#                country  year  fertility_rate
# 0          Afghanistan  1800            7.00
# 1              Albania  1800            4.60
# 2              Algeria  1800            6.99
# 3               Angola  1800            6.93
# 4  Antigua and Barbuda  1800            5.00

# %%
life.index
life.index.name = 'country'
#life.rename({'Life expectancy': 'country'}, axis = 1, inplace = True)
life = life.reset_index()
melt_life = life.melt(id_vars='country', var_name='year', value_name='life_rate')


melt_life.head()
# Out:
#                country  year  life_rate
# 0          Afghanistan  1800      28.21
# 1              Albania  1800      35.40
# 2              Algeria  1800      28.82
# 3               Angola  1800      26.98
# 4  Antigua and Barbuda  1800      33.54

# %%
pop = pd.read_excel('C:/Users/96650/OneDrive/Desktop/spiced_projects/sandbox/week_1/data/gapminder_population.xlsx', index_col=0)

# %%
#pop.dropna(inplace=True)
pop.index
pop.index.name = 'country'
#pop.rename({'Total population': 'country'}, axis = 1, inplace = True)

# %%
pop = pop.reset_index()
melt_pop = pop.melt(id_vars='country', var_name='year', value_name='population')

# %%
melt_pop.head()
# Out:
#                  country  year  population
# 0               Abkhazia  1800         NaN
# 1            Afghanistan  1800   3280000.0
# 2  Akrotiri and Dhekelia  1800         NaN
# 3                Albania  1800    410445.0
# 4                Algeria  1800   2503218.0

# %%
fertility_pop = pd.merge(left=melt_fertility, right=melt_pop, on=['country', 'year'], how='left')

# %%
life_fertility_pop = pd.merge(left=melt_life, right=fertility_pop, on=['country', 'year'], how='left')

# %%
life_fertility_pop.head()
# Out:
#                country  year  life_rate  fertility_rate  population
# 0          Afghanistan  1800      28.21            7.00   3280000.0
# 1              Albania  1800      35.40            4.60    410445.0
# 2              Algeria  1800      28.82            6.99   2503218.0
# 3               Angola  1800      26.98            6.93   1567028.0
# 4  Antigua and Barbuda  1800      33.54            5.00     37000.0

# %%
life_fertility_pop.dropna(inplace=True)

# %%
sns.heatmap(life_fertility_pop.isna())
# Out:
# <AxesSubplot:>

# %%
life_fertility_pop.head()
# Out:
#                country  year  life_rate  fertility_rate  population
# 0          Afghanistan  1800      28.21            7.00   3280000.0
# 1              Albania  1800      35.40            4.60    410445.0
# 2              Algeria  1800      28.82            6.99   2503218.0
# 3               Angola  1800      26.98            6.93   1567028.0
# 4  Antigua and Barbuda  1800      33.54            5.00     37000.0

# %%
df_subset = life_fertility_pop.loc[life_fertility_pop['year'] == 2000]
sns.scatterplot(x='life_rate', y='fertility_rate',
            data=df_subset, alpha=0.6)
# Out:
# <AxesSubplot:xlabel='life_rate', ylabel='fertility_rate'>

# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
sns.set_style('ticks')

years = range(1960, 2000)


for year in years:
    
    plt.figure()
    plt.clf()
    df_filter = life_fertility_pop[life_fertility_pop['year'] == year]
    
    
    size = df_filter['population']

    
    scatterplot = sns.scatterplot(data=df_filter, x='life_rate', y='fertility_rate',
                                  size=size, sizes=(20,2000), hue='country', alpha=0.5, legend=False)
   
    plt.axis((20, 100, 0, 10))

   
    plt.title('Life Expectancy vs Fertility' + str(year))
    plt.xlabel('Life Expectancy')
    plt.ylabel('fertility')
    plt.savefig('Life_Expectancy' + str(year) + '.png')
# Out:
# <ipython-input-38-c819101a4d1a>:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %%
pip install imageio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import imageio
import os

import imageio

images = []

for i in range(1960, 2015):
    filename = f'Life_Expectancy{i}.png'.format(i)
    images.append(imageio.imread(filename))

imageio.mimsave('Life Expectancy vs. Fertility(1969-2015).gif', images, fps=20)

# %%
#import imageio

#images = []

#for i in range(0, 100):
   # filename = 'lifeexp_{}.png'.format(i)
   # images.append(imageio.imread(filename))

#imageio.mimsave('output.gif', images, fps=20)
#Links
